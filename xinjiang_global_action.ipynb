# %%
import pandas as pd
import voila
import folium
from folium import plugins
import ipywidgets as widgets
from ipywidgets import Layout
# from IPython.display import display
from branca.element import Template, MacroElement

#dataframe populated from various source
df = pd.read_csv('international_human_rights_stance_china.csv')

# %%
# df.info(memory_usage = 'deep')

# %%
# df.tail(3)

# %%
# df = df.fillna('')

# %%
# import geopandas as gpd (keep in mind for future use)

# %%
#Retain below for adding greater label detail in future

# hooly = debate[['Country','UNHRC Debate Stance']]
# hooly = hooly.reset_index()
# hooly = hooly.drop(['index'], axis = 1)
# hooly = hooly.rename(columns = {'Country': 'name'})
# gdf_debate = gdf_debate.sort_values('name')
# gdf_debate_1 = gdf_debate.reset_index()
# gdf_debate = pd.merge(gdf_debate_1, hooly, how = 'left', on = 'name')
# gdf_debate = gdf_debate.drop(['index'], axis = 1)
# gdf_debate
# hi = gdf_debate[[any(a) for a in zip(gdf_debate['UNHRC Debate Stance'] == "Debate Abstention")]]
# df.tail(40)
# df['Total'].quantile((0,0.2,0.49,0.51,0.6,0.65,0.7,0.8,0.9,0.95,1)).tolist()

# %%
# %%html
# <style>
# @keyframes factor_boxes {
#   from {color: transparent;}
#   to {color: black;}
# }
#
# .top_graph{
#     width:auto;
#     background-color: transparent;
#     color: black;
#     font-family: Sansation;
#     animation: factor_boxes 2s ease forwards;
# }
#
# .page_container_1{
#     width:auto;
#     background-color: rgba(255, 255, 255, 0.3);
# }
#
# .header{
#     width:auto;
#     background: white;
#     color: black;
#     font-family: Antipasto Pro Extralight;
#     border-bottom: 1px solid black;
#     border-top: 1px solid black;
# }
#
# .header_1{
#     width:auto;
#     background: white;
#     color: black;
#     font-family: Antipasto Pro Thin;
#     font-size: 50px;
#     border-bottom: 1px solid black;
#     border-top: 1px solid black;
# }
#
# .footer{
#     width:auto;
#     background: black;
#     color: white;
#     font-family: Antipasto Pro Extralight;
#     border-top: 1px solid white;
# }
#
# .footer_1{
#     width:auto;
#     text-align: center;
#     background: black;
#     color: white;
#     font-family: Antipasto Pro Thin;
#     font-size: 25px;
#     border-top: 1px solid white;
# }
#
# .footer_combined{
#     background: black;
#     color: white;
# }
#
# .sub_header{
#     width:auto;
#     background-image: radial-gradient(circle, rgba(148,187,233,1) 0%, rgba(148,187,233,1) 100%);
#     color: #F4F7EB;
#     text-shadow: 0px 0px 6px rgba(255,255,255,0.7);
# }
# </style>
# Out:
# <style>
# @keyframes factor_boxes {
#   from {color: transparent;}
#   to {color: black;}
# }
#
# .top_graph{
#     width:auto;
#     background-color: transparent;
#     color: black;
#     font-family: Sansation;
#     animation: factor_boxes 2s ease forwards;
# }
#
# .page_container_1{
#     width:auto;
#     background-color: rgba(255, 255, 255, 0.3);
# }
#
# .header{
#     width:auto;
#     background: white;
#     color: black;
#     font-family: Antipasto Pro Extralight;
#     border-bottom: 1px solid black;
#     border-top: 1px solid black;
# }
#
# .header_1{
#     width:auto;
#     background: white;
#     color: black;
#     font-family: Antipasto Pro Thin;
#     font-size: 50px;
#     border-bottom: 1px solid black;
#     border-top: 1px solid black;
# }
#
# .footer{
#     width:auto;
#     background: black;
#     color: white;
#     font-family: Antipasto Pro Extralight;
#     border-top: 1px solid white;
# }
#
# .footer_1{
#     width:auto;
#     text-align: center;
# ...

# %%
# %%html
# <style>
#
# @keyframes mymove {
#     0% {border-bottom-color: transparent;}
#     12.5% {border-bottom-color: #909090;}
#     25% {border-bottom-color: transparent;}
#     37.5% {border-left-color: #686868;}
#     50% {border-left-color: transparent;}
#     62.5% {border-top-color: #303030;}
#     75% {border-top-color: transparent;}
#     87.5% {border-right-color: #080808;}
#     100% {border-right-color: transparent;}
# }
#
# .sub_header_2 {
#     font-family: Sansation;
#     font-size: 17px;
#     color: black;
#     background-image: radial-gradient(circle, rgba(5,117,250,0.01) 0%, rgba(255,255,255,1) 100%);
#     animation: factor_boxes 2s ease forwards;
# }
#
# .widget-button {
#     width:auto;
#     font-size: 20px;
#     background: transparent;
#     color: black;
#     font-family: Antipasto Pro DemiBold;
#     box-shadow: rgba(0, 0, 0, 0.09) 0px 3px 12px;
# }
#
# .widget-toggle-button.jupyter-button {
#     width:auto;
#     font-size: 15px;
#     background: transparent;
#     color: black;
#     font-family: Antipasto Pro DemiBold;
# }
#
# .supplementary_box :hover {
#     border: 3px solid transparent;
#     animation: mymove 0.5s;
#     animation-timing-function: linear;
#     animation-iteration-count: 1;
#     box-shadow: rgba(0, 0, 0, 0.4) 0px 4px 12px;
# }
#
# .layer_system_1 {
#     width:auto;
#     text-align: right;
#     color:white;
#     font-weight: bold;
#     font-size: 20px;
#     font-family: Sansation;
#     background-color: transparent;
#     border-right: 1px solid rgba(110,107,107,1);
#     text-shadow: -1px 1px 0 rgba(110,107,107,1),
#     1px 1px 0 rgba(110,107,107,1),
#     1px -1px 0 rgba(110,107,107,1),
#     -1px -1px 0 rgba(110,107,107,1);
# }
#
# .layer_system_2 {
#     width:auto;
#     color:white;
#     font-weight: bold;
#     font-size: 20px;
#     font-family: Sansation;
#     background-color: transparent;
#     border-right: 0.01px solid transparent;
#     text-shadow: -1px 1px 0 rgba(110,107,107,1),
#     1px 1px 0 rgba(110,107,107,1),
#     1px -1px 0 rgba(110,107,107,1),
#     -1px -1px 0 rgba(110,107,107,1);
# }
#
# .layer_system_3 {
#     width:auto;
#     text-align: right;
#     color:white;
#     font-weight: bold;
#     font-size: 20px;
#     font-family: Sansation;
#     background-color: transparent;
#     border-top: 1px solid rgba(110,107,107,1);
#     border-right: 1px solid rgba(110,107,107,1);
#     text-shadow: -1px 1px 0 rgba(110,107,107,1),
#     1px 1px 0 rgba(110,107,107,1),
#     1px -1px 0 rgba(110,107,107,1),
#     -1px -1px 0 rgba(110,107,107,1);
# }
#
# .layer_system_4 {
#     width:auto;
#     font-weight: bold;
#     font-size: 20px;
#     color:white;
#     font-family: Sansation;
#     background-color: transparent;
#     border-top: 1px solid rgba(110,107,107,1);
#     text-shadow: -1px 1px 0 rgba(110,107,107,1),
#     1px 1px 0 rgba(110,107,107,1),
#     1px -1px 0 rgba(110,107,107,1),
#     -1px -1px 0 rgba(110,107,107,1);
# }
# </style>
# Out:
# <style>
#
# @keyframes mymove {
#     0% {border-bottom-color: transparent;}
#     12.5% {border-bottom-color: #909090;}
#     25% {border-bottom-color: transparent;}
#     37.5% {border-left-color: #686868;}
#     50% {border-left-color: transparent;}
#     62.5% {border-top-color: #303030;}
#     75% {border-top-color: transparent;}
#     87.5% {border-right-color: #080808;}
#     100% {border-right-color: transparent;}
# }
#
# .sub_header_2 {
#     font-family: Sansation;
#     font-size: 17px;
#     color: black;
#     background-image: radial-gradient(circle, rgba(5,117,250,0.01) 0%, rgba(255,255,255,1) 100%);
#     animation: factor_boxes 2s ease forwards;
# }
#
# .widget-button {
#     width:auto;
#     font-size: 20px;
#     background: transparent;
#     color: black;
#     font-family: Antipasto Pro DemiBold;
#     box-shadow: rgba(0, 0, 0, 0.09) 0px 3px 12px;
# }
#
# .widget-toggle-button.jupyter-button {
#     width:auto;
#     font-size: 15px;
# ...

# %%
# %%html
# <style>
#
# @keyframes gradient {
#     0% {
#         background-position: 0% 50%;
#         color: transparent;
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, transparent, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#         text-decoration: underline transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     5% {
#         background-position: 1% 50%;
#         color: transparent;
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, black, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#
#     }
#     9% {
#         background-position: 1% 50%;
#         color: transparent;
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, black, black, transparent, transparent);
#         -webkit-mask-position: center;
#     }
#     16% {
#     background-position: 1% 50%;
#     color: transparent;
#     background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-45deg, black, black, black, rgba(0,0,0,0.8));
#     -webkit-mask-position: center;
#     }
#     50% {
#         background-position: 100% 50%;
#         color: transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#
#     }
#     100% {
#         background-position: 0% 50%;
#         color: rgba(255, 255, 255, 1);
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, black, black, black, rgba(0, 0, 0, 0.8));
#         -webkit-mask-position: center;
#         text-shadow: -1px 1px 0 rgba(110,107,107,1),
#         1px 1px 0 rgba(110,107,107,1),
#         1px -1px 0 rgba(110,107,107,1),
#         -1px -1px 0 rgba(110,107,107,1);
#         text-decoration: underline red;
#     }
# }
#
# @keyframes gradient_angle_1 {
#     0% {
#         background-position: 50% 1%;
#         color: transparent;
#         background: url(uyghur_human_rights_abuse.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-315deg, transparent, transparent, transparent, transparent);
#         -webkit-mask-position: left bottom;
#         text-decoration: underline transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     5% {
#         background-position: 50% 3%;
#         color: transparent;
#         background: url(uyghur_human_rights_abuse.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-315deg, transparent, transparent, transparent, black);
#         -webkit-mask-position: left bottom;
#     }
#     9% {
#         background-position: 50% 10%;
#         color: transparent;
#         background: url(uyghur_human_rights_abuse.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-315deg, transparent, transparent, black, black);
#         -webkit-mask-position: left bottom;
#     }
#     16% {
#     background-position: 50% 30%;
#     color: transparent;
#     background: url(uyghur_human_rights_abuse.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-315deg, rgba(0,0,0,0.8), black, black, black);
#     -webkit-mask-position: left bottom;
#     }
#     50% {
#         background-position: 50% 100%;
#         color: transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     100% {
#         background-position: 50% 0%;
#         color: rgb(255, 255, 255, 1);
#          background: url(uyghur_human_rights_abuse.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-315deg, rgba(0,0,0,0.8), black, black, black);
#         -webkit-mask-position: left bottom;
#         text-shadow: -1px 1px 0 rgba(110,107,107,1),
#         1px 1px 0 rgba(110,107,107,1),
#         1px -1px 0 rgba(110,107,107,1),
#         -1px -1px 0 rgba(110,107,107,1);
#         text-decoration: underline red;
#     }
# }
#
# @keyframes gradient_angle_2 {
#     0% {
#         background-position: 100% 50%;
#         color: rgba(255, 255, 255, 1);
#         background: url(reeducation.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-135deg, rgba(0,0,0,0.8), black, black, black);
#         -webkit-mask-position: center;
#         text-shadow: -1px 1px 0 rgba(110,107,107,1),
#         1px 1px 0 rgba(110,107,107,1),
#         1px -1px 0 rgba(110,107,107,1),
#         -1px -1px 0 rgba(110,107,107,1);
#         text-decoration: underline red;
#     }
#     50% {
#         background-position: 30% 70%;
#         color: transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     84% {
#     background-position: 100% 50%;
#     color: transparent;
#     background: url(reeducation.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-135deg, rgba(0,0,0,0.8), black, black, black);
#     -webkit-mask-position: center;
#
#     }
#     91% {
#     background-position: 100% 50%;
#     color: transparent;
#     background: url(reeducation.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-135deg, transparent, transparent, black, black);
#     -webkit-mask-position: center;
#     }
#     95% {
#     background-position: 100% 50%;
#     color: transparent;
#     background: url(reeducation.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-135deg, transparent, transparent, transparent, black);
#     -webkit-mask-position: center;
#
#     }
#
#     100% {
#         background-position: 100% 50%;
#         color: transparent;
#         background: url(reeducation.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-135deg, transparent, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#         text-decoration: underline transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#
#     }
# }
#
#
# @keyframes gradient_1 {
#     0% {
#         background-position: 50% 100%;
#         color: rgba(255, 255, 255, 1);
#         background: url(forced_labour.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, rgba(0,0,0,0.8), black, black, black);
#         -webkit-mask-position: center;
#         text-shadow: -1px 1px 0 rgba(110,107,107,1),
#         1px 1px 0 rgba(110,107,107,1),
#         1px -1px 0 rgba(110,107,107,1),
#         -1px -1px 0 rgba(110,107,107,1);
#         text-decoration: underline red;
#     }
#     50% {
#         background-position: 50% 0%;
#         color: transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     84% {
#     background-position: 50% 100%;
#     color: transparent;
#     background: url(forced_labour.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-45deg, rgba(0,0,0,0.8), black, black, black);
#     -webkit-mask-position: center;
#
#     }
#     91% {
#     background-position: 50% 100%;
#     color: transparent;
#     background: url(forced_labour.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-45deg, transparent, transparent, black, black);
#     -webkit-mask-position: center;
#
#     }
#     95% {
#     background-position: 50% 100%;
#     color: transparent;
#     background: url(forced_labour.PNG) no-repeat;
#     -webkit-mask-image: linear-gradient(-45deg, transparent, transparent, transparent, black);
#     -webkit-mask-position: center;
#
#     }
#
#     100% {
#         background-position: 50% 100%;
#         color: transparent;
#         background: url(forced_labour.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, transparent, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#         text-decoration: underline transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#
#
#     }
# }
#
# .layer_system_top_left {
#     width: auto;
#     color: transparent;
#     font-family: Sansation;
#     font-weight: bold;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 100% 100%;
#     border-top: 1px solid rgba(255,255,255,1);
#     border-left: 1px solid rgba(255,255,255,1);
# }
#
# .layer_system_top_left :hover {
#     width:auto;
#     color: transparent;
#     font-family: Sansation;
#     font-size: 18px;
#     background-image: transparent;
#     background-size: 200% 200%;
#     animation: gradient 1.5s ease forwards;
#     text-shadow: transparent;
# }
#
# .layer_system_bottom_left {
#     width: auto;
#     color: transparent;
#     font-family: Sansation;
#     font-weight: bold;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 100% 100%;
#     border-bottom: 1px solid rgba(255,255,255,1);
#     border-left: 1px solid rgba(255,255,255,1);
# }
#
# .layer_system_bottom_left :hover {
#     width:auto;
#     color: transparent;
#     font-family: Sansation;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 100% 100%;
#     animation: gradient_angle_1 1.5s ease forwards;
# }
#
# .layer_system_top_right {
#     width: auto;
#     color: transparent;
#     text-align: right;
#     font-family: Sansation;
#     font-weight: bold;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 100% 100%;
#     border-top: 1px solid rgba(255,255,255,1);
#     border-right: 1px solid rgba(255,255,255,1);
# }
#
# .layer_system_top_right :hover {
#     width:auto;
#     color: transparent;
#     text-align: right;
#     font-family: Sansation;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 200% 200%;
#     animation: gradient_angle_2 1.5s ease forwards reverse;
# }
#
# .layer_system_bottom_right {
#     width: auto;
#     color: transparent;
#     text-align: right;
#     font-family: Sansation;
#     font-weight: bold;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 200% 200%;
#     border-bottom: 1px solid rgba(255,255,255,1);
#     border-right: 1px solid rgba(255,255,255,1);
# }
#
# .layer_system_bottom_right :hover {
#     width:auto;
#     color: transparent;
#     text-align: right;
#     font-family: Sansation;
#     font-size: 18px;
#     text-decoration: underline transparent;
#     background-image: transparent;
#     background-size: 200% 200%;
#     animation: gradient_1 1.5s ease forwards reverse;
# }
#
# .graph_shadow {
#     box-shadow: rgba(0, 0, 0, 0.4) 0px 4px 12px;
#     text-align: center;
# }
#
# .mask1 {
#     width: 100%;
#     background: url(xinjiang_camp.PNG) no-repeat;
#     background-size: cover;
#     background-position: center;
#     -webkit-mask-image: black;
#     mask-image: black;
#     -webkit-mask-position: center;
# }
#
# </style>
# Out:
# <style>
#
# @keyframes gradient {
#     0% {
#         background-position: 0% 50%;
#         color: transparent;
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, transparent, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#         text-decoration: underline transparent;
#         text-shadow: -1px 1px 0 transparent,
#         1px 1px 0 transparent,
#         1px -1px 0 transparent,
#         -1px -1px 0 transparent;
#     }
#     5% {
#         background-position: 1% 50%;
#         color: transparent;
#         background: url(xinjiang_satellite_detention_camp.PNG) no-repeat;
#         -webkit-mask-image: linear-gradient(-45deg, black, transparent, transparent, transparent);
#         -webkit-mask-position: center;
#
#     }
#     9% {
#         background-position: 1% 50%;
#         color: transparent;
# ...

# %%
#create output widget to contain map
out_20 = widgets.Output()

map_title = widgets.HTML(value= "<p style='text-align:center'><font size = 4><b>Tracking the Global Political Response to Human Rights Abuses Against Uyghurs<b></p>",
                          layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1.4% 1% 0% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
map_title = map_title.add_class('top_graph')

box_20 = widgets.VBox(children = [out_20],
                    layout = Layout(#border = '1.5px solid orange',
                                    display = 'block',
                                    padding = '6px 1px 1px 20px',
                                    margin = '1% 5% 2% 5%',
                                    align_items = 'center',
                                    width = 'auto',
                                    height = 'auto'
                                    )
                   )
box_20 = box_20.add_class('graph_shadow')

with out_20:
    #base map
    world = folium.Map(location=[0,0], zoom_start=2, tiles=None, height = '100%', width = '100%', prefer_canvas = False)
    folium.TileLayer('cartodbpositron',name="light mode",control=True, max_zoom=6, min_zoom=1.5, noWrap=False).add_to(world)
    folium.TileLayer('cartodbdark_matter',name="dark mode",control=True, max_zoom=6, min_zoom=1.5, noWrap=False).add_to(world)
    
    #json coordinates data
    wc = r'world_coordinates.json'
    
    #scale for legend bins
    custom_scale = (df['Total'].quantile((0,0.2,0.49,0.51,0.6,0.65,0.7,0.8,0.9,0.95,1)).tolist())
    
    #create choropleth
    choropleth = folium.Choropleth(geo_data=wc,
                                    data=df,
                                    columns=['Country', 'Total'],
                                    key_on='feature.properties.name',
                                    fill_color='PiYG',
                                    fill_opacity=0.8,
                                    line_opacity=0.2,
                                    smooth_factor = 0,
                                    nan_fill_color = "#4D4DFF",
                                    nan_fill_opacity = 0.8,
                                    legend_name="Total Joint UN Statements For (+) / Against (-) Adressing Uyghur Human Rights Abuse in China",
                                    bins = 10,
                                    name = 'Country Stance on China Human Rights Abuse'
                                    ).add_to(world)
    choropleth.geojson.add_child(folium.features.GeoJsonTooltip(['name'], labels=False))

    debate_layer_add = folium.features.GeoJsonTooltip(['name'], labels=False)


#     geojson to geopandas dataframe
#     gdf = gpd.read_file(wc)

    #pattern
    sp = plugins.pattern.StripePattern(angle=45, 
                                       color='brown', #F6F0CF
                                       space_color='transparent', 
                                       space_weight = 4, 
                                       weight = 2,
                                       opacity = 1)
    sp.add_to(world)

    tp = plugins.pattern.StripePattern(angle=-45, 
                                       color='black', 
                                       space_color='transparent', 
                                       space_weight = 4, 
                                       weight = 2,
                                       opacity = 1)
    tp.add_to(world)

    # circles = plugins.pattern.CirclePattern(width=20, 
    #                                         height=20, 
    #                                         radius=5, 
    #                                         fill_opacity=0.5,
    #                                         opacity=1)
    # circles.add_to(world)

    # debate = df[df['UNHRC Debate Stance'].isin(['Debate', 'No Debate', 'Debate Abstention'])]
    # debate_1 = debate['Country']              
    # gdf_debate = gdf[gdf['name'].isin(debate_1)]

    # hooly = debate[['Country','UNHRC Debate Stance']]
    # hooly = hooly.reset_index()
    # hooly = hooly.drop(['index'], axis = 1)
    # hooly = hooly.rename(columns = {'Country': 'name'})
    # gdf_debate = gdf_debate.sort_values('name')
    # gdf_debate_1 = gdf_debate.reset_index()
    # gdf_debate = pd.merge(gdf_debate_1, hooly, how = 'left', on = 'name')
    # gdf_debate = gdf_debate.drop(['index'], axis = 1)
    
    #styles for GeoJson layer
    def whats_your_style(feature): #df[[any([a, b]) for a, b in zip(df.C > 0.25, df.C < -0.25)]]

        default_style = {
                        'opacity':1,
                        'fillColor': 'transparent',
                        'fillopacity': 0,
                        'color': 'black',
                        'weight': 0.05
                        }
        if feature['properties']['name'] in {'Czech Republic','Finland','France','Germany','Honduras','Japan','Lithuania','Luxembourg','Montenegro','Netherlands','Paraguay','Poland','Republic of Korea','Somalia','United Kingdom', 'United States of America'}:
            default_style['color'] = 'Cyan'
            default_style['opacity'] = 0.6
            default_style['weight'] = 1.5

        if feature['properties']['name'] in {'Bolivia','Cameroon','China','Cote d Ivoire','Cuba','Eritrea','Gabon','Indonesia','Kazakhstan','Mauritania','Namibia','Nepal','Pakistan','Qatar','Senegal','Sudan','United Arab Emirates','Uzbekistan','Venezuela'}:
            default_style['color'] = 'red'
            default_style['opacity'] = 0.7
            default_style['weight'] = 1.5

        if feature['properties']['name'] in {'Argentina','Armenia','Benin','Brazil','Gambia','India','Libya','Malawi','Malaysia','Mexico','Ukraine'}:
            default_style['color'] = '#FFA836'
            default_style['opacity'] = 0.9
            default_style['weight'] = 1.5
        
        if feature['properties']['name'] in {'Nauru', 'Turkey', 'United States of America'}:
            default_style['fillPattern'] = sp
            default_style['opacity'] = 1
            default_style['weight'] = 0.2
        
        if feature['properties']['name'] in {'Bangladesh', 'Grenada', 'Nigeria', 'Tonga', 'Tunisia'}:
            default_style['fillPattern'] = tp
            default_style['opacity'] = 0
            default_style['weight'] = 1
        
        if feature['properties']['name'] in {'United States of America'}:
            default_style['fillPattern'] = sp
            default_style['weight'] = 1.5
            default_style['color'] = 'Cyan'
            default_style['opacity'] = 0.6

        return default_style
    
    #highlight
#     highlight_function = lambda x: {'fillColor': 'black',  
#                                     'fillOpacity': 0.05,
#                                     'weight': 1}

    # adding the debate layer with `sp` as the fillPattern
    debate_layer = folium.GeoJson(data=wc, 
                                  name = 'Vote Status on UNHRC A/HRC/51/L.6 (whether on not to debate Human Rights in China)', 
                                  style_function = whats_your_style,
#                                   highlight_function = highlight_function,
                                  tooltip = debate_layer_add
                                 ).add_to(world)


    folium.LayerControl().add_to(world)
    
    #create additional legend
    template = """
    {% macro html(this, kwargs) %}

    <!doctype html>
    <html lang="en">
    <head>
      <meta charset="utf-8">
      <meta name="viewport" content="width=device-width, initial-scale=1">
      <title>jQuery UI Draggable - Default functionality</title>
      <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

      <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
      <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>

      <script>
      $( function() {
        $( "#maplegend" ).draggable({
                        start: function (event, ui) {
                            $(this).css({
                                right: "auto",
                                top: "auto",
                                bottom: "auto"
                            });
                        }
                    });
    });

      </script>
    </head>
    <body>


    <div id='maplegend' class='maplegend' 
        style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
         border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>

    <div class='legend-title'>Additional Info   &#8697;</div>
    <div class='legend-scale'>
      <ul class='legend-labels'>
        <li><span style='border-color:cyan;opacity:0.7;'></span>In Favour of UNHRC debate</li>
        <li><span style='border-color:red;opacity:0.7;'></span>Against UNHRC debate</li>
        <li><span style='border-color:#FFA836;opacity:0.7;'></span>Abstained UNHRC debate</li>
        <li><span style='background:blue;opacity:0.7;'></span>Unknown stance</li>
        <li><span style='background: linear-gradient(45deg, #b3860b 25%, #F6F0CF 25%, #F6F0CF 50%, #b3860b 50%, #b3860b 75%, #F6F0CF 75%, #F6F0CF 100%);opacity:0.7;'></span>Inconsistent Support "For"</li>
        <li><span style='background: linear-gradient(-45deg, #080808 25%, #F6F0CF 25%, #F6F0CF 50%, #080808 50%, #080808 75%, #F6F0CF 75%, #F6F0CF 100%);opacity:0.7;'></span>Inconsistent Support "Against"</li>

      </ul>
    </div>
    </div>

    </body>
    </html>

    <style type='text/css'>
      .maplegend .legend-title {
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }
      .maplegend .legend-scale ul {
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }
      .maplegend .legend-scale ul li {
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }
      .maplegend ul.legend-labels li span {
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 1px solid #999;
        }
      .maplegend .legend-source {
        font-size: 80%;
        color: #777;
        clear: both;
        }
      .maplegend a {
        color: #777;
        } 

    .legend {
        padding: 0px 0px;
        font: 10px sans-serif;
        background: white;
        background: rgba(255,255,255,0.8);
        box-shadow: 0 0 15px rgba(0,0,0,0.2);
        border-radius: 5px;
    }

    .key path {
      display: none;
    }

    </style>
    {% endmacro %}"""

    macro = MacroElement()
    macro._template = Template(template)

    world.get_root().add_child(macro)
    display(world)

# display(box_20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 #create output widget to contain map
# ----> 2 out_20 = widgets.Output()
#       4 map_title = widgets.HTML(value= "<p style='text-align:center'><font size = 4><b>Tracking the Global Political Response to Human Rights Abuses Against Uyghurs<b></p>",
#       5                           layout = Layout(#align_content = 'stretch',
#       6                                   width = 'auto',
#    (...)
#      12                                   )
#      13                             )
#      14 map_title = map_title.add_class('top_graph')
#
# NameError: name 'widgets' is not defined

# %%
#header part 1
heading = widgets.HTML(
        value= "<p style='text-align:left'><font size = 5><b> Be<br/>the<br/>Change </p>",
        layout = Layout(width = '10%',
                        #display = 'flex',
                        #grid_area = 'header',
                        #border = '2px solid #44428B',
                        padding = '5px 5px 5px 5px',
                        margin = '0% 0% 0% 0%',
                       )
)
heading = heading.add_class('header')

#header part 2
heading_1 = widgets.HTML(
        value= "<p style='line-height: 1'>A Global View: <br/><font size = 20px>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Human Rights Abuse Against Uyghurs<font size = 1><p style='text-align:right'><a href=https://www.change.org/p/stand-up-for-the-uyghur-muslims-in-china-antonioguterres-amnesty-un><font color='black'>Stand Up for Uyghurs Petition | </a><a href=https://www.ohchr.org/sites/default/files/documents/countries/2022-08-31/22-08-31-final-assesment.pdf><font color='black'>OHCHR Assessment </a></p>",
        layout = Layout(width = '90%',
                        #display = 'flex',
                        #grid_area = 'header',
                        #border = '2px solid #44428B',
                        padding = '13px 1px 13px 5px',
                        margin = '0% 0% 0% 0%',
                       )
)
heading_1 = heading_1.add_class('header_1')

heading_combined = widgets.HBox([heading, heading_1],
                                 layout = Layout(width = 'auto',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '1px solid #000000',
                                                padding = '1px 1px 1px 1px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )

# display(heading_combined, layer_system_grid_complete, footing_combined)

# %%
#Linkedin and github images/links
img =  widgets.HTML('<div id="img" style="float:right">'
                    '<a href="https://www.linkedin.com/in/russellmcgavock/"><img style="align:middle" src="In-White-34-Γö¼┬½.png" alt="" </a>'                       
                    '</div>',
                   layout = Layout(width = '5%',
                                #display = 'flex',
                                #grid_area = 'header',
                                #border = '2px solid #44428B',
                                padding = '5px 0px 0px 0px',
                                margin = '1% 0% 0% 0%',
                               )
                   )
img = img.add_class('footer')

img_1 =  widgets.HTML('<div id="img" style="float:middle">'
                    '<a href="https://github.com/RRBMc"><img style="align:middle" src="GitHub-Mark-Light-32px.png" alt=""></a>'                       
                    '</div>',
                      layout = Layout(width = '5%',
                                    #display = 'flex',
                                    #grid_area = 'header',
                                    #border = '2px solid #44428B',
                                    padding = '5px 0px 0px 10px',
                                    margin = '1% 0% 0% 0%',
                                   )
                   )
img_1 = img_1.add_class('footer')

# %%
#footer part 1
footing = widgets.HTML(
        value= "<p style='text-align:left'><font size = 5><b> Be<br/>the<br/>Change </p>",
        layout = Layout(width = '10%',
                        #display = 'flex',
                        #grid_area = 'header',
                        #border = '2px solid #44428B',
                        padding = '5px 5px 5px 5px',
                        margin = '1% 0% 0% 0%',
                       )
)
footing = footing.add_class('footer')

#footer part 2
footing_1 = widgets.HTML(
        value= "<p style='line-height: 1'>Tracking the Geopolitical Perspective on Human Rights Abuses in the Xinjiang Uyghur Autonomous Region<br/> <font size = 3>Seeking Information Transparency</p>",
        layout = Layout(width = '80%',
                        #display = 'flex',
                        #grid_area = 'header',
                        #border = '2px solid #44428B',
                        padding = '5px 13px 13px 13px',
                        margin = '1% 0% 0% 0%',
                       )
)
footing_1 = footing_1.add_class('footer_1')

footing_combined = widgets.HBox([footing, footing_1, img, img_1],
                                 layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                border = '1px solid #000000',
                                                padding = '10px 0px 1px 1px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )
footing_combined = footing_combined.add_class('footer_combined')

# %%
#create togglebuttons and widgets invoked on selection - page 1
Factor = widgets.HTML(
                      value= "<p style='text-align:left'><font size = 2><span style='background-color:rgba(0,255,0,0.2)'><b>Method</b></span><br/> Collect data referring to “Joint Statements” made by countries through the United Nations. Specifically, any statements made and supported by multiple countries addressing the human rights situation in the Xinjiang Uyghur Autonomous Region, China. All “Joint Statements” included are binary, i.e. either condemning and/or expressing concern citing human rights abuses against Uyghurs in China <b>OR</b> supporting non-interference in China’s internal affairs and/or human rights issues. </p>",
                      layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Factor = Factor.add_class('top_graph')

Comment = widgets.HTML(value= "<p style='text-align:left'><font size = 2><span style='background-color:rgba(0,255,0,0.2)'><b>Geographical Representation</b></span><br/>A global map based on the collected and collated data enables the visualisation of international division on the issue. It will also convey how consistent a country’s stance on the issue has been, how many joint statements the country has participated in and how the country has voted on issues regarding Uyghur human rights abuses at UNHRC meetings.  </p>",
                          layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Comment = Comment.add_class('top_graph')

# style = dict(description_width = )

Deduction = widgets.HTML(value= "<p style='text-align:left'><font size = 2>Looking at days of the week, the total incident numbers of Monday, Tuesday, Thursday and Saturday are almost indentical and should be condsidered the 'baseline'.<br/>This leaves Wednesday, Friday and Sunday as outliers, deviating significantly in percentage terms from the baseline. In order to grasp what distinguishes these days, incident density indicates increased incident rates around the end of the typical working day on Wednesday and a dramatic increase on Friday. Incident rate spikes on Fridays are highly likely due to the transition from work week to weekend, with more of the population engaging socially and disengaging from work routine. Rationalisation of Wednesday's elevated incident density is less clear. Nonetheless, it is possible that midweek social drinking - post-work - accounts for a degree of the rise. Sunday's incident rate is markedly lower and highly likely due to traditional American work and religious Sunday routine. Reduced commuting almost certainly lowers related incident types such as theft, vehicle theft, traffic violation, assault and burglary as more of the population remain at home. </a></p>",
                          layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Deduction = Deduction.add_class('top_graph')

# button = widgets.ToggleButtons(options = [('Factor', 0), ('Comment', 1), ('Deduction', 2)], value = None)

t_button = widgets.ToggleButtons(options = [('How', Factor), 
                                            ('What', Comment), 
                                            ],
                                 layout = Layout(width = 'auto',
                                                 padding = '2px, 2px, 2px, 2px',
                                                 align_items = 'center',
                                                 ),
                                 style = {'button_width': '89px'}
                                )
# t_button = t_button.add_class('top_graph_1')

# display(button, output)

def on_button_clicked(Select):
    display(Select)

heloo = widgets.interactive_output(on_button_clicked, {'Select': t_button})


heloo = widgets.VBox([t_button, heloo],
                            layout = Layout(
                                            width = 'auto',
                                            margin = '1% 1% 1% 1%'
                                            )
                           )



combo_box = widgets.VBox([heloo])

# %%
#create togglebuttons and widgets invoked on selection - page 2

Factor_1 = widgets.HTML(
                      value= "<p style='text-align:left'><font size = 2><span style='background-color:rgba(0,255,0,0.2)'><b>Notes</b></span><br/>- The country 'scoring system' is not intended as a measure of its strength of position but to show both how consistent a countries position on Uyghur Human Rights abuses is and enable users to identify nuances in the global political response.<br/>- This resource is a work-in-progress and will be updated as and when information is available or sourced.<br/>- Any and all information gaps regarding the data presented are in the process of being filled. In some cases sourcing is challenging. Feedback is appreciated.<br/></p>",
                        layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Factor_1 = Factor_1.add_class('top_graph')

Comment_1 = widgets.HTML(value= "<p style='text-align:left'><font size = 2>- 'The Human Rights Council is an inter-governmental body within the United Nations system made up of 47 States responsible for the promotion and protection of all human rights around the globe. It has the ability to discuss all thematic human rights issues and situations that require its attention throughout the year. It meets at the UN Office at Geneva.'</p>",
                          layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Comment_1 = Comment_1.add_class('top_graph')

t_button_1 = widgets.ToggleButtons(options = [('Context', Factor_1),
                                              ('UNHRC', Comment_1)
                                             ],
                                 layout = Layout(width = 'auto',
                                                 padding = '2px, 2px, 2px, 2px',
                                                 align_items = 'center',
                                                 ),
                                 style = {'button_width': '89px'}
                                )
# t_button_1 = t_button_1.add_class('top_graph_1')

# display(button, output)

def on_button_clicked_1(Select):
    display(Select)

heloo_1 = widgets.interactive_output(on_button_clicked_1, {'Select': t_button_1})


heloo_1 = widgets.VBox([t_button_1, heloo_1],
                            layout = Layout(
                                            width = '100%',
                                            margin = '1% 0% 1% 0%',
                                            padding = '1px 1px 1px px'
                                            )
                           )



combo_box_1 = widgets.VBox([box_20, heloo_1],
                            layout = Layout(
#                                             width = '100%',
                                            #border = '1px solid black',
                                            margin = '0% 0% 0% 0%',
                                            )
                           )

# %%
#create togglebuttons and widgets invoked on selection - page 3

Factor_2 = widgets.HTML(
                      value= "<p style='text-align:left'><font size = 2><span style='background-color:rgba(0,255,0,0.2)'><b>Work in progress</b></span><br/>Supplement existing global map with Chinese state foreign investment data.<br/><br/>Investigate the feasibility of economically quantifying diplomatic support for China on human rights issues. Is there an identifiable ratio, such as Chinese  investment total to national GDP, that sets a threshold for obligatory backing of China in global forum’s like the UN?<br/><br/>Fill existing information gaps on national stances regarding human rights abuses against Uyghurs and Turkic Muslims.</p>",
                      layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Factor_2 = Factor_2.add_class('top_graph')

Comment_2 = widgets.HTML(value= "<p style='text-align:left'><font size = 2><span style='background-color:rgba(0,255,0,0.2)'><b>Further reading</b></span><br/>1. Countries in China’s Belt and Road Initiative: Who’s In And Who’s Out, David Sacks, 24 Mar 21, Council on Foreign Relations - https://www.cfr.org/blog/countries-chinas-belt-and-road-initiative-whos-and-whos-out<br/>2. 'China Global Investment Tracker', American Enterprise Institute and the Heritage Foundation - https://www.aei.org/china-global-investment-tracker/<br/>3. “Break Their Lineage, Break Their Roots” China’s Crimes against Humanity Targeting Uyghurs and Other Turkic Muslims, 19 Apr 2021, Human Rights Watch - https://www.hrw.org/report/2021/04/19/break-their-lineage-break-their-roots/chinas-crimes-against-humanity-targeting</a></p>",
                          layout = Layout(#align_content = 'stretch',
                                  width = 'auto',
                                  #grid_area = 'header', 
                                  padding = '2px 2px 2px 2px',
                                  margin = '1% 1% 1% 1%',
                                  #border = '1.5px solid #A6DDF9',
                                  align_items = 'center'
                                  )
                            )
Comment_2 = Comment_2.add_class('top_graph')


#toggle button widget
t_button_2 = widgets.ToggleButtons(options = [('Horizon', Factor_2), 
                                              ('Resources', Comment_2)],
                                 layout = Layout(width = 'auto',
                                                 padding = '2px, 2px, 2px, 2px',
                                                 align_items = 'center',
                                                 ),
                                 style = {'button_width': '89px'}
                                )


def on_button_clicked_2(Select):
    display(Select)

heloo_2 = widgets.interactive_output(on_button_clicked_2, {'Select': t_button_2})


heloo_2 = widgets.VBox([t_button_2, heloo_2],
                            layout = Layout(
                                            width = '100%',
                                            margin = '1% 0% 1% 0%',
                                            padding = '1px 1px 1px px'
                                            )
                           )



combo_box_2 = widgets.VBox([heloo_2])

# %%
#set buttons for main body interactive portion and widgets invoked on click

layer_1 = widgets.Button(
                        description = 'Intent',
                        style=dict(
#                                    button_color = "yellow",
                                  ),
                        disabled = False,
                        layout = Layout(width = '100%',
                                        #border = '1.5px solid #F4F7EB',
                                        align_items = 'center',
                                        margin = '1% 5% 3% 5%',
                                        padding = '1px 1px 1px 1px')
                        )


layer_2 = widgets.Button(
                        description = 'Global Map',
                        style=dict(
#                                    button_color = "green",
                                  ),
                        disabled = False,
                        layout = Layout(width = '100%',
                                        #border = '1.5px solid #F4F7EB',
                                        align_items = 'center',
                                        margin = '1% 5% 1% 5%',
                                        padding = '1px 1px 1px 1px')
                        )


layer_3 = widgets.Button(
                        description = 'Perspective',
                        style=dict(
#                                    button_color = "gray",
                                  ),
                        disabled = False,
                        layout = Layout(width = '100%',
                                        #border = '1.5px solid #F4F7EB',
                                        align_items = 'center',
                                        margin = '1% 5% 1% 5%',
                                        padding = '1px 1px 1px 1px')
                        )

layer_4 = widgets.Button(
                        description = 'Sources',
                        style=dict(
#                                    button_color = "red",
                                  ),
                        disabled = False,
                        layout = Layout(width = '100%',
                                        #border = '1.5px solid #F4F7EB',
                                        align_items = 'center',
                                        margin = '1% 5% 1% 5%',
                                        padding = '1px 1px 1px 1px')
                        )

layer_explain_1 = widgets.HTML(
                                value = "<b>Objectives</b><br/> <br/><b>Collate and visualise </b> current and past official positions of every nation regarding human rights abuses against Uyghurs in China since the implementation of the “Strike Hard Campaign against Violent Terrorism” (May 2014) in the Xinjiang Ughyur Autonomous Region. <br/><br/> <b>Maintain a record</b> of each nation’s position as it has developed since 2016. <br/><br/> <b> Provide a resource </b> for quick reference to ascertain whether a nation has taken and expressed an official position, determine if a nation has voiced concern against the treatment of Uyghurs or supported non-interference in China’s internal affairs, and capture the consistency and relative frequency of each nation's proclamations of support.",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '1px solid grey',
                                                padding = '1px 10px 1px 10px',
                                                margin = '0% 0% 0% 0%',
                                               )
                               )
layer_explain_1 = layer_explain_1.add_class('sub_header_2')

layer_explain_2 = widgets.HTML(
                                value = "<b>Reading the Map</b><br/><br/> The map separates countries into 2 primary categories:<br/><b>1</b>. “For” - Condemning and/or expressing concern citing human rights abuses against Uyghurs in China.<br/><b>2</b>.  “Against” - Supporting non-interference in China’s internal affairs and/or human rights issues.<br/><br/>The number of “Joint Statements” a country has supported is tallied, with “For” receiving a (+1) and “Against” a (-1).<br/> Countries who have participated in statements on either side but have not supported subsequent statements are highlighted, indicating an inconsistent stance that may demand further interrogation. <br/><br/>Additional (secondary) categories include:<br/><b>1</b>. How a country sitting on the UNHRC council voted in the ‘draft decision entitled debate on the situation of human rights in the Xinjiang Uyghur Autonomous Region, China on 6 Oct 22 (whether to debate Human Rights abuses in China at the UNHRC or not) <br/><b>2</b>. Unknown stance (the countries have not participated in “Joint UN Statements” either for or against raising concerns.",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '1px solid grey',
                                                padding = '1px 10px 1px 10px',
                                                margin = '0% 0% 0% 0%',
                                               )
                               )

layer_explain_2 = layer_explain_2.add_class('sub_header_2')

layer_explain_3 = widgets.HTML(
                                value = "<b>The Utility of Tracking A Nation's Posture on Human Rights Abuses in China</b><br/><br/>Geopolitically, the issue of human rights abuses in China stretches across the opinion spectrum from treatment considered indefensible to quiet neutrality and on toward vocal solidarity or sympathy. Yet the matter is rarely, in a global political forum, considered anything short of sensitive. Countries’ governments ponder, dither and recoil from the consequences of openly clashing with a version of China that has extended state power worldwide, intertwining the reliance and prosperity of many nations with Chinese state interests. A government must carefully weigh several questions that together form a moral and political dilemma: <font size = 2><br/><br/>- How will going against China’s narrative impact Chinese investment in the country?<br/>- Would our infrastructure (current and future projects) be adversely affected?<br/>- Is trade with China going to become more difficult or expensive?<br/>- How can damage to diplomatic relations, trade and investment be mitigated?<br/>- What are the moral customs of our country and what action do they demand be taken? <br/>- What action does our population demand?<br/><br/><font size = 4px>The reflective, internal theme of debate for each nation is unavoidably and, in the instance of some developing countries, unashamedly economic, then moral.<br/><br/>This resource seeks to act as a visual tracker of the open stance of each nation to provide a source of reference and, moreover, a launching point for investigations on the complicated relationships and conduits of power connecting China and the rest of the world. The global map may perform the role of keeping interested individuals informed and up to date in order to maintain an awareness of how their country or their neighbour’s country is interpreting and upholding human rights standards. <u>The primary utility is to inform</u>.<br/><br/>The aspirational utility is to stimulate questions that may lead to insightful research and greater understanding of the complexity of confronting human rights issues in China and the intricate, obscure, and sometimes bewildering melange of factors shaping the intersection where morals and geopolitics collide.",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '1px solid grey',
                                                padding = '1px 10px 1px 10px',
                                                margin = '0% 0% 0% 0%',
                                               )
                               )

layer_explain_3 = layer_explain_3.add_class('sub_header_2')

layer_explain_4 = widgets.HTML(
                                value = "<b>Images</b><br/>1. Vocational skills education centre in Dabancheng in Xinjiang Uighur Autonomous Region, China 4 Sep, 2018. REUTERS/Thomas Peter<br/>2. Uyghur women work in a cloth factory in Hotan county, Xinjiang province, China. | Azamat Imanaliev/Shutterstock<br/>3. Uyghurs treated as second-class citizens by China, Human Rights House Foundation, 25 Nov 2009, original reporting in Mandarin by Xi Wang. Mandarin service director: Jennifer Chou. Translated and written for the Web in English by Luisetta Mudie<br/><br/><b>Data</b><br/>1. About HRC, United Nations Human Rights Council, ohchr.org/en/hrbodies/hrc/home<br/>2. Human Rights Council Adopts 21 Texts and Rejects One Draft Decision, Extends Mandates on Older Persons, Right to Development, Arbitrary Detention, Mercenaries, Slavery, Indigenous Peoples, Safe Drinking Water and Sanitation, United Nations Human Rights Council, 6 Oct 2022, ohchr.org/en/news/2022/10/human-rights-council-adopts-21-texts-and-rejects-one-draft-decision-extends- mandates#:~:text=The%20Council%20rejected%20a%20draft%20decision%20(A%2FHRC%2F51,19%20against%20and% 2011%20abstentions<br/>3. Joint Statement Delivered by Cuba on Behalf of 69 Countries at the 50th session of the Human Rights Council, 16 Jun 2022, PERMANENT MISSION OF THE PEOPLE'S REPUBLIC OF CHINA TO THE UNITED NATIONS OFFICE AT GENEVA AND OTHER INTERNATIONAL ORGANIZATIONS IN SWITZERLAND<br/>4. UN Human Rights Council 50: Joint Statement on the Human Rights Situation in China, UK Mission to the WTO, UN and Other International Organisations (Geneva), 14 Jun 2022<br/>5. Joint Statement Delivered by Pakistan on Behalf of a Group of Countries at the 51st session of the Human Rights Council, 26 Sep 22, PERMANENT MISSION OF THE PEOPLE'S REPUBLIC OF CHINA TO THE UNITED NATIONS OFFICE AT GENEVA AND OTHER INTERNATIONAL ORGANIZATIONS IN SWITZERLAND<br/>6. Human rights situation in Xinjiang: joint statement, Foreign, Commonwealth & Development Office and Ambassador Nicolas de Rivière, Permanent Representative of France to the UN,21 October 2021<br/>7. UN: Unprecedented Joint Call for China to End Xinjiang Abuses, Human Rights Watch, 10 Jul 2019<br/>8. JOINT STATEMENT – HUMAN RIGHTS SITUATION IN CHINA, Delivered by U.S. Ambassador to the HRC Keith Harper, U.S. MISSION TO INTERNATIONAL ORGANIZATIONS IN GENEVA, 10 Mar 2016<br/>9. [Research Reports] China and the Joint Statement on Xinjiang and Hong Kong, 15 Sep 2021, Jun Kumakura (Associate Professor, Hosei University), Japan Institute of International Affairs<br/>10. OHCHR Assessment of human rights concerns in the Xinjiang Uyghur Autonomous Region, People’s Republic of China, 31 Aug 2022, United Nations Human Rights Office of the High Commissioner<br/>11. “Break Their Lineage, Break Their Roots” China’s Crimes against Humanity Targeting Uyghurs and Other Turkic Muslims, 19 Apr 2021, Human Rights Watch - https://www.hrw.org/report/2021/04/19/break-their-lineage-break-their-roots/chinas-crimes-against-humanity-targeting<br/>12. Forced Labor in China’s Xinjiang Region, FACT SHEET, OFFICE TO MONITOR AND COMBAT TRAFFICKING IN PERSONS,  1 Jul 2021, US Department of State",
                                layout = Layout(width = 'auto',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '1px solid grey',
                                                padding = '1px 10px 1px 10px',
                                                margin = '0% 0% 0% 0%',
                                               )
                               )

layer_explain_4 = layer_explain_4.add_class('top_graph')

out_5 = widgets.Output()
with out_5:
    display(layer_explain_1, combo_box)

def switchMode(x):
    out_5.clear_output()
    with out_5:
        display(layer_explain_1, combo_box)
        
def switchermode(x):
    out_5.clear_output()
    with out_5:
        display(layer_explain_2, map_title, combo_box_1)

def SwitchMode(x):
    out_5.clear_output()
    with out_5:
        display(layer_explain_3, combo_box_2)

def switcherMode(x):
    out_5.clear_output()
    with out_5:
        display(layer_explain_4)


layer_1.on_click(switchMode)
layer_2.on_click(switchermode)
layer_3.on_click(SwitchMode)
layer_4.on_click(switcherMode)


supplementary_box_1 = widgets.Box([layer_1],
                                layout = Layout(width = '100%',
                                #display = 'flex',
                                #grid_area = 'header',
                                #border = '3px dotted red',
                                padding = '0px 0px 0px 0px',
                                margin = '0% 0% 0% 0%',
                                               )
                               )

supplementary_box_1 = supplementary_box_1.add_class('supplementary_box')

supplementary_box_2 = widgets.Box([layer_2],
                                layout = Layout(width = '100%',
                                #display = 'flex',
                                #grid_area = 'header',
                                #border = '3px dotted red',
                                padding = '0px 0px 0px 0px',
                                margin = '0% 0% 0% 0%',
                                               )
                               )

supplementary_box_2 = supplementary_box_2.add_class('supplementary_box')

supplementary_box_3 = widgets.Box([layer_3],
                                layout = Layout(width = '100%',
                                #display = 'flex',
                                #grid_area = 'header',
                                #border = '3px dotted red',
                                padding = '0px 0px 0px 0px',
                                margin = '0% 0% 0% 0%',
                                               )
                               )

supplementary_box_3 = supplementary_box_3.add_class('supplementary_box')

supplementary_box_4 = widgets.Box([layer_4],
                                layout = Layout(width = '100%',
                                #display = 'flex',
                                #grid_area = 'header',
                                #border = '3px dotted red',
                                padding = '0px 0px 0px 0px',
                                margin = '0% 0% 0% 0%',
                                               )
                               )

supplementary_box_4 = supplementary_box_4.add_class('supplementary_box')


layer_box = widgets.HBox([supplementary_box_1, supplementary_box_2, supplementary_box_3, supplementary_box_4],
                         layout = Layout(width = 'auto',
                                        #display = 'flex',
                                        #grid_area = 'header',
                                        #border = '2px solid #44428B',
                                        padding = '1px 1px 1px 1px',
                                        margin = '0% 0% 2% 0%',
                                       )
                        )

# %%
#sub-header interactive box with image/text mask animations added - ref html above

out_21 = widgets.Output()
widgets.VBox(children = [out_21],
                    layout = Layout(#border = '1.5px solid orange',
                                    display = 'block',
                                    padding = '0px 0px 0px 0px',
                                    margin = '0% 0% 0% 0%',
                                    align_items = 'center',
                                    width = 'auto',
                                    height = 'auto'
                                    )
                   )

with out_21:
    
    inset_system_1 = widgets.HTML(
                                value= "Detention &#8662;",
                                layout = Layout(width = '60%',
                                                display = 'flex',
    #                                             align_items = 'flex-end',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '0px 14px 0px 14px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    inset_system_1 = inset_system_1.add_class('layer_system_1')


    inset_system_2 = widgets.HTML(
                                value= "&#8663; Re-education",
                                layout = Layout(width = '60%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '0px 14px 0px 14px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    inset_system_2= inset_system_2.add_class('layer_system_2')


    inset_system_3 = widgets.HTML(
                                value= "Abuse &#8665;",
                                layout = Layout(width = '60%',
                                                display = 'flex',
    #                                             align_items = 'flex-end',
                                                #border_bottom = '2px solid #44428B',
                                                padding = '0px 14px 0px 14px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    inset_system_3 = inset_system_3.add_class('layer_system_3')

    inset_system_4 = widgets.HTML(
                                value= "&#8664; Forced Labour",
                                layout = Layout(width = '60%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '0px 14px 0px 14px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    inset_system_4 = inset_system_4.add_class('layer_system_4')

    layer_system_1 = widgets.HTML(
                                value= "Up to 1 Million people <br/>Estimated to have been unjustly detained<br/> In detention facilities<br/><br/><br/>",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '1px 18px 1px 18px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    layer_system_1 = layer_system_1.add_class('layer_system_top_left')

    layer_system_2 = widgets.HTML(
                                value= "Uyghur and other Turkic Muslims<br/>Placed in 'Political Education' camps<br/>For periods between 2 - 18 months<br/>Drugged, violated and deprived of liberty<br/><br/>",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '1px 18px 1px 18px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    layer_system_2 = layer_system_2.add_class('layer_system_top_right')

    layer_system_3 = widgets.HTML(
                                value= "Alleged torture<br/> Cruel, inhuman, and degrading <br/>Treatment of detainees<br/>Hundreds reported dead<br/><br/>",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border_bottom = '2px solid #44428B',
                                                padding = '1px 18px 1px 18px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    layer_system_3 = layer_system_3.add_class('layer_system_bottom_left')

    layer_system_4 = widgets.HTML(
                                value= "A materials & manufacturing industry<br/>Powered by state-sponsored forced labour <br/>Under the guise of 'poverty alleviation'<br/>A cornerstone of 're-education'<br/><br/>",
                                layout = Layout(width = '100%',
                                                #display = 'flex',
                                                #grid_area = 'header',
                                                #border = '2px solid #44428B',
                                                padding = '1px 18px 1px 18px',
                                                margin = '0% 0% 0% 0%',
                                               )
                                )


    layer_system_4 = layer_system_4.add_class('layer_system_bottom_right')



    layer_system_grid_1 = widgets.VBox([layer_system_1, inset_system_1, inset_system_3, layer_system_3],
                                      layout = Layout(width = '100%',
                                                      display = 'flex',
                                                      align_items = 'flex-end',
                                                      margin = '0% 0% 0% 0%',
                                                      )
                                      )

    layer_system_grid_2 = widgets.VBox([layer_system_2, inset_system_2, inset_system_4, layer_system_4],
                                       layout = Layout(width = '100%',
                                                       display = 'flex',
                                                       align_items = 'flex-start',
                                                       margin = '0% 0% 0% 0%',
                                                       )
                                      )
    layer_system_grid_complete = widgets.HBox([layer_system_grid_1, layer_system_grid_2],
                                              layout = Layout(width = 'auto',
    #                                                         display = 'flex',
                                                            #border = '1px solid black',
                                                            align_items = 'center',
                                                            padding = '3px 50px 3px 50px',
                                                            margin = '1% 1.5% 2.2% 1.5%',
                                                               )
                                             )

    layer_system_grid_complete = layer_system_grid_complete.add_class('mask1')

    display(layer_system_grid_complete)

# %%
#Full page container for all widgets

page_container = widgets.VBox([heading_combined, layer_system_grid_complete, layer_box, out_5, footing_combined]) #lower_supplementary_box_1, out_6, lower_supplementary_box_2, out_7, layer_explain_4, combo_box_3])

page_container = page_container.add_class('page_container_1')

page_container
